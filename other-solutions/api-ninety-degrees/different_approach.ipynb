# %%
import json
import urllib.request
import time
import numpy as np
from datetime import timedelta, datetime
from scipy.signal import argrelextrema

# %%
# API Wrapper

year = 2030

url = fr"https://ssd.jpl.nasa.gov/api/horizons.api?format=json&COMMAND='301'&OBJ_DATA='YES'&MAKE_EPHEM='YES'&EPHEM_TYPE='OBSERVER'&CENTER='500@399'&START_TIME='{year}-05-26'&STOP_TIME='{year}-07-30'&STEP_SIZE='1h'&QUANTITIES='24"

# %%
# #Looking for a pattern for thirteen night month

# def test(year):
#     url = fr"https://ssd.jpl.nasa.gov/api/horizons.api?format=json&COMMAND='301'&OBJ_DATA='YES'&MAKE_EPHEM='YES'&EPHEM_TYPE='OBSERVER'&CENTER='500@399'&START_TIME='{year}-05-26'&STOP_TIME='{year}-07-30'&STEP_SIZE='1h'&QUANTITIES='24"
#     response = urllib.request.urlopen(url)
#     result = json.loads(response.read())
#     data = result['result'].partition('$$SOE')[2].partition('$$EOE')[0]
#     times = data.split('\n')[1:-1]
#     stos = np.array([times[i].split() for i in range(len(times))])
#     stos_cleaned = stos[:,2].astype(float)
#     new_moon = argrelextrema(stos_cleaned, np.greater)[0]
#     TWENTYTHREEDAYS = timedelta(days=23)
#     NINETEENJUNE = datetime(year, 6, 19)

#     for i in range(len(new_moon)):
#         tangaroa = datetime.strptime(stos[new_moon[i]][0], '%Y-%b-%d') + TWENTYTHREEDAYS
#         if tangaroa >= NINETEENJUNE:
#             month_start_index = i
#             break
            
#     start = datetime.strptime(stos[new_moon[month_start_index]][0], '%Y-%b-%d')
#     start += timedelta(hours=int(stos[new_moon[month_start_index]][1].split(':')[0]))
#     end = datetime.strptime(stos[new_moon[month_start_index+1]][0], '%Y-%b-%d')
#     end += timedelta(hours=int(stos[new_moon[month_start_index+1]][1].split(':')[0]))

#     month_days = end - start
#     print(f'start: {start.strftime("%m/%d/%Y, %H:%M:%S")}')
#     print(f'end: {end.strftime("%m/%d/%Y, %H:%M:%S")}')
#     print(f'duration: {month_days}')
#     return False if month_days.days<29 else True

# %%
# for year in range(2022, 2053):
#     print(f'{year}: {test(year)}')

# %%
response = urllib.request.urlopen(url)

# %%
result = json.loads(response.read())

# %%
data = result['result'].partition('$$SOE')[2].partition('$$EOE')[0]
data
# Out:
# '\n 2030-May-26 00:00     110.8406\n 2030-May-26 01:00     111.3170\n 2030-May-26 02:00     111.7929\n 2030-May-26 03:00     112.2685\n 2030-May-26 04:00     112.7436\n 2030-May-26 05:00     113.2182\n 2030-May-26 06:00     113.6925\n 2030-May-26 07:00     114.1664\n 2030-May-26 08:00     114.6398\n 2030-May-26 09:00     115.1129\n 2030-May-26 10:00     115.5855\n 2030-May-26 11:00     116.0578\n 2030-May-26 12:00     116.5297\n 2030-May-26 13:00     117.0012\n 2030-May-26 14:00     117.4723\n 2030-May-26 15:00     117.9431\n 2030-May-26 16:00     118.4135\n 2030-May-26 17:00     118.8835\n 2030-May-26 18:00     119.3532\n 2030-May-26 19:00     119.8225\n 2030-May-26 20:00     120.2915\n 2030-May-26 21:00     120.7602\n 2030-May-26 22:00     121.2285\n 2030-May-26 23:00     121.6964\n 2030-May-27 00:00     122.1641\n 2030-May-27 01:00     122.6314\n 2030-May-27 02:00     123.0984\n 2030-May-27 03:00     123.5651\n 2030-May-27 04:00     124.0315\n 2030-May-27 05:00     124.4975\n 2030
# ...

# %%
times = data.split('\n')[1:-1]
stos = np.array([times[i].split() for i in range(len(times))])

stos.tolist()
# Out:
# [['2030-May-26', '00:00', '110.8406'],
#  ['2030-May-26', '01:00', '111.3170'],
#  ['2030-May-26', '02:00', '111.7929'],
#  ['2030-May-26', '03:00', '112.2685'],
#  ['2030-May-26', '04:00', '112.7436'],
#  ['2030-May-26', '05:00', '113.2182'],
#  ['2030-May-26', '06:00', '113.6925'],
#  ['2030-May-26', '07:00', '114.1664'],
#  ['2030-May-26', '08:00', '114.6398'],
#  ['2030-May-26', '09:00', '115.1129'],
#  ['2030-May-26', '10:00', '115.5855'],
#  ['2030-May-26', '11:00', '116.0578'],
#  ['2030-May-26', '12:00', '116.5297'],
#  ['2030-May-26', '13:00', '117.0012'],
#  ['2030-May-26', '14:00', '117.4723'],
#  ['2030-May-26', '15:00', '117.9431'],
#  ['2030-May-26', '16:00', '118.4135'],
#  ['2030-May-26', '17:00', '118.8835'],
#  ['2030-May-26', '18:00', '119.3532'],
#  ['2030-May-26', '19:00', '119.8225'],
#  ['2030-May-26', '20:00', '120.2915'],
#  ['2030-May-26', '21:00', '120.7602'],
#  ['2030-May-26', '22:00', '121.2285'],
#  ['2030-May-26', '23:00', '121.6964'],
# ...

# %%
stos_cleaned = stos[:,2].astype(float)

new_moon = argrelextrema(stos_cleaned, np.greater)[0]
print(new_moon)
# Out:
# [150 861]

# %%
stos[new_moon[0]]
# Out:
# array(['2030-Jun-01', '06:00', '179.4507'], dtype='<U11')

# %%
stos[new_moon[1]]
# Out:
# array(['2030-Jun-30', '21:00', '177.9614'], dtype='<U11')

# %%
from datetime import datetime, timedelta

TWENTYTHREEDAYS = timedelta(days=23)
NINETEENJUNE = datetime(year, 6, 19)

for i in range(len(new_moon)):
    tangaroa = datetime.strptime(stos[new_moon[i]][0], '%Y-%b-%d') + TWENTYTHREEDAYS
    if tangaroa >= NINETEENJUNE:
        month_start_index = i
        break
        
tangaroa
# Out:
# datetime.datetime(2030, 6, 24, 0, 0)

# %%
def isThirtyNightsMonth():
    start = datetime.strptime(stos[new_moon[month_start_index]][0], '%Y-%b-%d')
    start += timedelta(hours=int(stos[new_moon[month_start_index]][1].split(':')[0]))
    end = datetime.strptime(stos[new_moon[month_start_index+1]][0], '%Y-%b-%d')
    end += timedelta(hours=int(stos[new_moon[month_start_index+1]][1].split(':')[0]))
    
    month_days = end - start
    
    print(month_days)
    return False if month_days.days<29 else True

isThirtyNightsMonth()
# Out:
# 29 days, 15:00:00
# True

# %%
## getClosestFriday depending on thirty night month or not

# def getClosestFriday(d0, thirtyNights):
#     if thirtyNights:
#         # If it's a Saturday, the previous Friday is chosen instead of the next
#         if (d0.weekday() < 4):
#             return d0+timedelta(4-d0.weekday())
#         else:
#             return d0-timedelta(d0.weekday()-4)
#     else:

# %%
def getClosestFriday(d0):
    if (d0.weekday() < 4):
        matariki =  d0+timedelta(4-d0.weekday())
    else:
        matariki =  d0-timedelta(d0.weekday()-4)
        
    if matariki < NINETEENJUNE:
        matariki+=timedelta(days=7)
                           
    return matariki

# %%
matariki = getClosestFriday(tangaroa).strftime('%Y-%m-%d')
matariki
# Out:
# '2030-06-28'
